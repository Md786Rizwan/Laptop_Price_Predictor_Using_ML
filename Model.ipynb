# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C://Users//imdri//OneDrive//Desktop//Cost_Price_Prediction_Training to deplyment//laptop_data (2).csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
data.shape
# Out:
# (1303, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
data.drop(columns=['Unnamed: 0'], inplace= True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
data['Ram'] = data['Ram'].str.replace('GB'," ")
data['Weight'] = data['Weight'].str.replace('kg', " ")

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34    47895.5232
# ...

# %%
data['Ram']  =data['Ram'].astype('int32')
data['Weight'] = data['Weight'].astype('float32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns

# %%
sns.distplot(data['Price'])
# Out:
# C:\Users\imdri\AppData\Local\Temp\ipykernel_18128\4196895882.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=data['Company'], y=data['Price'])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
sns.barplot(x = data['Company'], y = data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=data['TypeName'], y=data['Price'])
# Out:
# <Axes: xlabel='TypeName', ylabel='Price'>

# %%
sns.distplot(data['Inches'])
# Out:
# C:\Users\imdri\AppData\Local\Temp\ipykernel_18128\1445398758.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=data['Inches'], y= data['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
data['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
data['Touchscreen'] = data['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
data.sample(5)
# Out:
#       Company   TypeName  Inches             ScreenResolution  \
# 437    Google  Ultrabook    12.3        Touchscreen 2400x1600
# 511      Acer   Notebook    15.6            Full HD 1920x1080
# 1122       HP   Notebook    14.0            Full HD 1920x1080
# 874   Samsung  Ultrabook    15.0            Full HD 1920x1080
# 354   Toshiba   Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram     Memory                    Gpu  \
# 437    Intel Core i7 7Y75 1.3GHz   16  512GB SSD  Intel HD Graphics 615
# 511   Intel Core i7 7500U 2.7GHz    4  500GB HDD   Nvidia GeForce 940MX
# 1122  Intel Core i5 6200U 2.3GHz    8  256GB SSD  Intel HD Graphics 520
# 874   Intel Core i7 7500U 2.7GHz   16  256GB SSD   Nvidia GeForce 940MX
# 354   Intel Core i7 6500U 2.5GHz   16  512GB SSD    Nvidia GeForce 930M
#
#            OpSys  Weight      Price  Touchscreen
# 437    Chrome OS    1.10  117162.72            1
# 511   Windows 10    2.20   34045.92            0
# ...

# %%
data['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=data['Touchscreen'], y=data['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
data['Ips'] = data['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
data['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=data['Ips'], y=data['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
sns.barplot(x=data['Ips'], y=data['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = data['ScreenResolution'].str.split('x' , n=1, expand=True)

# %%
data['x_res'] = new[0]
data['y_res'] = new[1]

# %%
data.sample(10)
# Out:
#       Company   TypeName  Inches                 ScreenResolution  \
# 59       Asus   Notebook    15.6                Full HD 1920x1080
# 1147     Dell   Notebook    15.6                Full HD 1920x1080
# 28       Dell  Ultrabook    15.6                Full HD 1920x1080
# 840      Asus     Gaming    17.3                Full HD 1920x1080
# 2          HP   Notebook    15.6                Full HD 1920x1080
# 471        HP   Notebook    15.6                Full HD 1920x1080
# 604      Dell   Notebook    15.6                         1366x768
# 474      Asus   Notebook    15.6  IPS Panel 4K Ultra HD 3840x2160
# 1176   Lenovo   Notebook    15.6                Full HD 1920x1080
# 606   Toshiba   Notebook    15.6      IPS Panel Full HD 1920x1080
#
#                               Cpu  Ram                  Memory  \
# 59       Intel Core i3 6006U 2GHz    4               256GB SSD
# 1147   Intel Core i7 7500U 2.7GHz    8               256GB SSD
# ...

# %%
data['x_res'] = data['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
data['x_res'] = data['x_res'].astype('int')
data['y_res'] = data['y_res'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
data['Inches'] = pd.to_numeric(data['Inches'], errors='coerce')

# %%
# Check if there are any NaN values
print(data[['x_res', 'y_res', 'Inches']].isnull().sum())
# Out:
# x_res     0
# y_res     0
# Inches    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
# Now perform the PPI calculation safely
data['ppi'] = (((data['x_res']**2) + (data['y_res']**2))**0.5 / data['Inches']).astype(float)

# %%
data.drop(columns=['ScreenResolution'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips  x_res  y_res         ppi
# 0   71378.6832            0    1   2560   1600  226.983005
# 1   47895.5232            0    0   1440    900  127.677940
# ...

# %%
data.drop(columns=['Inches','x_res','y_res'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
data['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
data['CpuName'] = data['Cpu'].apply(lambda x:' '.join(x.split()[0:3]))

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi        CpuName
# ...

# %%
data['CpuName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
data['cpu_brand'] = data['CpuName'].apply(fetch_processor)

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi        CpuName      cpu_brand
# ...

# %%
data['cpu_brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=data['cpu_brand'], y= data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data.drop(columns=['CpuName'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      cpu_brand
# ...

# %%
sns.histplot(x=data['cpu_brand'], y= data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=data['Ram'], y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      cpu_brand
# ...

# %%
# Ensure that the 'Memory' column exists
if 'Memory' in data.columns:
    # Clean non-numeric characters in the 'first' and 'second' columns
    data['Memory'] = data['Memory'].str.replace('GB', '')
    data['Memory'] = data['Memory'].str.replace('TB', '000')
    
    # Split the 'Memory' column to extract 'first' and 'second'
    new = data['Memory'].str.split("+", n=1, expand=True)

    data['first'] = new[0].str.strip()
    data['second'] = new[1].fillna("0").str.strip()

    # Apply storage type classification for Layer1
    data['Layer1HDD'] = data['first'].apply(lambda x: 1 if "HDD" in x else 0)
    data['Layer1SSD'] = data['first'].apply(lambda x: 1 if "SSD" in x else 0)
    data['Layer1Hybrid'] = data['first'].apply(lambda x: 1 if "Hybrid" in x else 0)
    data['Layer1Flash_Storage'] = data['first'].apply(lambda x: 1 if "Flash Storage" in x else 0)

    # Remove non-numeric characters in 'first' after extracting storage type
    data['first'] = data['first'].str.replace(r'\D', '', regex=True)

    # Handle missing values in 'second' and apply storage type classification for Layer2
    data['Layer2HDD'] = data['second'].apply(lambda x: 1 if "HDD" in x else 0)
    data['Layer2SSD'] = data['second'].apply(lambda x: 1 if "SSD" in x else 0)
    data['Layer2Hybrid'] = data['second'].apply(lambda x: 1 if "Hybrid" in x else 0)
    data['Layer2Flash_Storage'] = data['second'].apply(lambda x: 1 if "Flash Storage" in x else 0)

    # Remove non-numeric characters in 'second'
    data['second'] = data['second'].str.replace(r'\D', '', regex=True)

    # Convert 'first' and 'second' to numeric, filling any invalid data with 0
    data['first'] = pd.to_numeric(data['first'], errors='coerce').fillna(0).astype(int)
    data['second'] = pd.to_numeric(data['second'], errors='coerce').fillna(0).astype(int)

    # Calculate total storage for each type
    data['HDD'] = (data['first'] * data['Layer1HDD']) + (data['second'] * data['Layer2HDD'])
    data['SSD'] = (data['first'] * data['Layer1SSD']) + (data['second'] * data['Layer2SSD'])
    data['Hybrid'] = (data['first'] * data['Layer1Hybrid']) + (data['second'] * data['Layer2Hybrid'])
    data['Flash_Storage'] = (data['first'] * data['Layer1Flash_Storage']) + (data['second'] * data['Layer2Flash_Storage'])

    # Drop unnecessary columns
    data.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 
                       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 
                       'Layer2Flash_Storage'], inplace=True)

# Check the updated DataFrame
print(data)
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
data.sample(5)
# Out:
#      Company            TypeName                         Cpu  Ram   Memory  \
# 798   Lenovo  2 in 1 Convertible  Intel Core i7 7500U 2.7GHz    8  256 SSD
# 649   Lenovo           Ultrabook  Intel Core i7 7500U 2.7GHz    8  256 SSD
# 63      Asus            Notebook  Intel Core i5 8250U 1.6GHz    8  256 SSD
# 1115    Dell           Ultrabook  Intel Core i7 7560U 2.4GHz    8  256 SSD
# 219     Dell  2 in 1 Convertible  Intel Core i7 8550U 1.8GHz   16  512 SSD
#
#                                Gpu       OpSys  Weight     Price  Touchscreen  \
# 798          Intel HD Graphics 620  Windows 10    1.38  71874.72            1
# 649          Intel HD Graphics 620  Windows 10    1.36  84395.52            0
# 63          Intel UHD Graphics 620  Windows 10    1.40  50136.48            0
# 1115  Intel Iris Plus Graphics 640  Windows 10    1.23  73473.12            0
# 219         Intel UHD Graphics 620  Windows 10    1.62  68145.12            1
#
# ...

# %%
data.drop(columns=['Memory'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      cpu_brand  HDD  SSD  Hybrid  Flash_Storage
# 0  226.983005  Intel Core i5    0  128       0              0
# ...

# %%
data.drop(columns=['Hybrid', 'Flash_Storage'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      cpu_brand  HDD  SSD
# 0  226.983005  Intel Core i5    0  128
# 1  127.677940  Intel Core i5    0    0
# 2  141.211998  Intel Core i5    0  256
# ...

# %%
data['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
data['GpuBrand'] = data['Gpu'].apply(lambda x:x.split()[0])

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      cpu_brand  HDD  SSD GpuBrand
# 0  226.983005  Intel Core i5    0  128    Intel
# 1  127.677940  Intel Core i5    0    0    Intel
# ...

# %%
data['GpuBrand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: GpuBrand, dtype: int64

# %%
data = data[data['GpuBrand'] != 'ARM']

# %%
data['GpuBrand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data.drop(columns=['Gpu'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram  OpSys  Weight  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8  macOS    1.37
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  macOS    1.34
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8  No OS    1.86
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16  macOS    1.83
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      cpu_brand  HDD  SSD GpuBrand
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128    Intel
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0    Intel
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256    Intel
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512      AMD
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256    Intel

# %%
data.drop(columns=['Cpu'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      cpu_brand  HDD  SSD GpuBrand
# 0  226.983005  Intel Core i5    0  128    Intel
# 1  127.677940  Intel Core i5    0    0    Intel
# 2  141.211998  Intel Core i5    0  256    Intel
# 3  220.534624  Intel Core i7    0  512      AMD
# 4  226.983005  Intel Core i5    0  256    Intel

# %%
data['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=data['OpSys'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
data['os'] = data['OpSys'].apply(cat_os)

# %%
data.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      cpu_brand  HDD  SSD GpuBrand                  os
# 0  226.983005  Intel Core i5    0  128    Intel                 Mac
# 1  127.677940  Intel Core i5    0    0    Intel                 Mac
# 2  141.211998  Intel Core i5    0  256    Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512      AMD                 Mac
# 4  226.983005  Intel Core i5    0  256    Intel                 Mac

# %%
data.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=data['os'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(data['Weight'])
# Out:
# C:\Users\imdri\AppData\Local\Temp\ipykernel_18128\2799343561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=data['Weight'], y=data['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Ram          1302 non-null   int32
#  3   Weight       1302 non-null   float32
#  4   Price        1302 non-null   float64
#  5   Touchscreen  1302 non-null   int64
#  6   Ips          1302 non-null   int64
#  7   ppi          1302 non-null   float64
#  8   cpu_brand    1302 non-null   object
#  9   HDD          1302 non-null   int64
#  10  SSD          1302 non-null   int64
#  11  GpuBrand     1302 non-null   object
#  12  os           1302 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 132.2+ KB

# %%
data.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        cpu_brand  HDD  SSD GpuBrand                  os
# 0  Intel Core i5    0  128    Intel                 Mac
# 1  Intel Core i5    0    0    Intel                 Mac
# 2  Intel Core i5    0  256    Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512      AMD                 Mac
# 4  Intel Core i5    0  256    Intel                 Mac

# %%
X = data.drop(columns=['Price'])
y = np.log(data['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
X_test
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 248       HP            Notebook    4    1.49            0    1  165.632118
# 555     Asus            Notebook    4    2.00            0    0  100.454670
# 1251      HP            Notebook    4    1.86            0    0  100.454670
# 547   Lenovo            Notebook    4    2.15            0    0  141.211998
# 885       HP  2 in 1 Convertible    4    1.28            1    0  165.632118
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1129      HP              Gaming    8    3.35            0    1  127.335675
# 172   Lenovo            Notebook    4    2.20            0    0  100.454670
# 322     Asus            Notebook    8    2.00            0    0  157.350512
# 996       HP           Ultrabook    8    1.11            1    1  165.632118
# 470       HP  2 in 1 Convertible    8    1.29            1    1  331.264236
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor, GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
print(X_train.dtypes)
print(X_train.head())
# Out:
# Company         object
# TypeName        object
# Ram              int32
# Weight         float32
# Touchscreen      int64
# Ips              int64
# ppi            float64
# cpu_brand       object
# HDD              int64
# SSD              int64
# GpuBrand        object
# os              object
# dtype: object
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
#
#                   cpu_brand   HDD  SSD GpuBrand                  os
# 183           Intel Core i5     0  128    Intel             Windows
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, VotingRegressor
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# Ensure categorical columns are UTF-8 encoded
for col in ['Company', 'TypeName', 'cpu_brand', 'GpuBrand', 'os']:
    X_train[col] = X_train[col].str.encode('utf-8').str.decode('utf-8')
    X_test[col] = X_test[col].str.encode('utf-8').str.decode('utf-8')

# %%
X_train.head()
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
#
#                   cpu_brand   HDD  SSD GpuBrand                  os
# 183           Intel Core i5     0  128    Intel             Windows
# 1141          Intel Core i7  1000  128   Nvidia             Windows
# 1049  Other Intel Processor     0    0    Intel  Others/No OS/Linux
# 1020          Intel Core i3  1000    0    Intel             Windows
# 878           Intel Core i5  1000  128   Nvidia             Windows

# %% [markdown]
# # Linearn Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'), [0,1,7,10,11])
],remainder='passthrough')

step2  = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('Re score', r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Re score 0.8076027104032486
# MAE 0.20997250416188487

# %% [markdown]
# # Ridge

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'), [0,1,7,10,11])
],remainder='passthrough')

step2  = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('Re score', r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Re score 0.8128383472213984
# MAE 0.2091145810296459

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'), [0,1,7,10,11])
],remainder='passthrough')

step2  = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('Re score', r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Re score 0.8075178111156666
# MAE 0.210866285059053

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'), [0,1,7,10,11])
],remainder='passthrough')

step2  = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('Re score', r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Re score 0.8032374966391982
# MAE 0.192323155454726

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'), [0,1,7,10,11])
],remainder='passthrough')

step2  = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('Re score', r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Re score 0.8514399757636657
# MAE 0.17673806343384701

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'), [0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('Re score', r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# Re score 0.8110307380700476
# MAE 0.202157461457922

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8867784498604531
# MAE 0.15846401923279707

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                            random_state=3,
                            bootstrap=False,  # Keep bootstrap sampling disabled
                            max_features=0.75,
                            max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.876464706700947
# MAE 0.16043855566088625

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7984128394642565
# MAE 0.22661985580231755

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8792982670708754
# MAE 0.16077596749082992

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8756143069582513
# MAE 0.16490587155562805

# %%
# Step 1: OneHotEncode categorical variables
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

# Step 2: Define ensemble models
rf = RandomForestRegressor(n_estimators=350, random_state=3, max_samples=0.5, max_features=0.75, max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100, max_features=0.5)
xgb = XGBRegressor(n_estimators=25, learning_rate=0.3, max_depth=5)
et = ExtraTreesRegressor(n_estimators=100, random_state=3, max_samples=0.5, bootstrap=True, max_features=0.75, max_depth=10)

# Step 3: Voting Regressor
step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb', xgb), ('et', et)], weights=[5, 1, 1, 1])

# Step 4: Create the pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Step 5: Fit the pipeline
pipe.fit(X_train, y_train)

# Step 6: Make predictions
y_pred = pipe.predict(X_test)

# Step 7: Evaluate the model
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8889919992937051
# MAE: 0.15835734750183783

# %%
data.head()
# Out:
#   Company   TypeName Ram Weight               Price Touchscreen Ips  \
# 0   Apple  Ultrabook   8   1.37          71378.6832           0   1
# 1   Apple  Ultrabook   8   1.34          47895.5232           0   0
# 2      HP   Notebook   8   1.86             30636.0           0   0
# 3   Apple  Ultrabook  16   1.83  135195.33599999998           0   1
# 4   Apple  Ultrabook   8   1.37           96095.808           0   1
#
#                   ppi      cpu_brand HDD  SSD GpuBrand                  os
# 0  226.98300468106115  Intel Core i5   0  128    Intel                 Mac
# 1  127.67794013309688  Intel Core i5   0    0    Intel                 Mac
# 2  141.21199808219862  Intel Core i5   0  256    Intel  Others/No OS/Linux
# 3  220.53462386625827  Intel Core i7   0  512      AMD                 Mac
# 4  226.98300468106115  Intel Core i5   0  256    Intel                 Mac

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.879373456293572
# MAE 0.16578403551806167

# %%
import pickle

pickle.dump(data,open('data.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
data.head()
# Out:
#   Company   TypeName Ram Weight               Price Touchscreen Ips  \
# 0   Apple  Ultrabook   8   1.37          71378.6832           0   1
# 1   Apple  Ultrabook   8   1.34          47895.5232           0   0
# 2      HP   Notebook   8   1.86             30636.0           0   0
# 3   Apple  Ultrabook  16   1.83  135195.33599999998           0   1
# 4   Apple  Ultrabook   8   1.37           96095.808           0   1
#
#                   ppi      cpu_brand HDD  SSD GpuBrand                  os
# 0  226.98300468106115  Intel Core i5   0  128    Intel                 Mac
# 1  127.67794013309688  Intel Core i5   0    0    Intel                 Mac
# 2  141.21199808219862  Intel Core i5   0  256    Intel  Others/No OS/Linux
# 3  220.53462386625827  Intel Core i7   0  512      AMD                 Mac
# 4  226.98300468106115  Intel Core i5   0  256    Intel                 Mac
